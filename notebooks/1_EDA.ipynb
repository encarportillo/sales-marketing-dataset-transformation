# %%
# Importar librerias necesarias
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.api.types import is_float_dtype, is_integer_dtype

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from src.Routes import RUTAS

# %%
# Carga de datos
df = pd.read_excel(RUTAS['data_raw'] / 'Dirty_Sales_Marketing_Dataset.xlsx')
df.head()
# Out:
#   customer_id    gender     age  country     city signup_date  \
# 0    10001.0      MALE     nan     India   Berlin  2022-05-10
# 1    10002.0       nan    35.0   Germany   Mumbai  2024-06-16
# 2    10003.0    female    27.0   Germany      NaN  2023-08-23
# 3    10004.0    FEMALE    36.0     India   Mumbai  2024-01-28
# 4    10005.0      MALE    29.0       USA  Hamburg  2023-07-21
#
#   last_purchase_date acquisition_channel device_type subscription_type  ...  \
# 0         2024-12-31               Email      Tablet            Annual  ...
# 1         2024-05-07             Organic     Desktop           Monthly  ...
# 2         2024-04-28               Email      Mobile            Annual  ...
# 3         2023-05-20        Facebook Ads      Tablet            Annual  ...
# 4         2024-04-07            Referral      Mobile           Monthly  ...
#
#    support_tickets  refund_requested  delivery_delay_days  payment_method  \
# 0                0                 0                    3             UPI
# 1                5                 0                    3           BKash
# 2                1                 0                    2             UPI
# 3                0                 0                    2          PayPal
# 4                2                 1                    4           BKash
#
#    satisfaction_score  nps_score  marketing_spend_per_user  lifetime_value  \
# 0                 3.0         10                     27.56      915.310827
# 1                 3.0          7                     15.15     2079.960938
# 2                 5.0          6                     13.51     1379.150885
# 3                 4.0          6                     25.65      774.652684
# 4                 3.0          1                     12.39       87.680409
#
#    last_3_month_purchase_freq churn
# 0                          14     0
# 1                          11     0
# 2                           9     0
# 3                           7     0
# 4                          11     0
#
# [5 rows x 30 columns]

# %%
# Vista general del dataset
print('Shape dataset completo:', df.shape)
print('Cantidad de columnas:', len(df.columns))
print('Columnas del dataset:')
print(df.columns.tolist())
# Out:
# Shape dataset completo: (15750, 30)
# Cantidad de columnas: 30
# Columnas del dataset:
# ['customer_id', 'gender', 'age', 'country', 'city', 'signup_date', 'last_purchase_date', 'acquisition_channel', 'device_type', 'subscription_type', 'is_premium_user', 'total_visits', 'avg_session_time', 'pages_per_session', 'email_open_rate', 'email_click_rate', 'total_spent', 'avg_order_value', 'discount_used', 'coupon_code', 'support_tickets', 'refund_requested', 'delivery_delay_days', 'payment_method', 'satisfaction_score', 'nps_score', 'marketing_spend_per_user', 'lifetime_value', 'last_3_month_purchase_freq', 'churn']

# %%
# Revisión de estructura y tipos de datos del dataset
print('INFO del dataset:')
print(df.info())

print('\nTipos de datos por columna:')
print(df.dtypes)
# Out:
# INFO del dataset:
# <class 'pandas.DataFrame'>
# RangeIndex: 15750 entries, 0 to 15749
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 15750 non-null  str
#  1   gender                      15750 non-null  str
#  2   age                         15750 non-null  str
#  3   country                     14165 non-null  str
#  4   city                        14185 non-null  str
#  5   signup_date                 15750 non-null  datetime64[us]
#  6   last_purchase_date          15750 non-null  datetime64[us]
#  7   acquisition_channel         15750 non-null  str
#  8   device_type                 15750 non-null  str
#  9   subscription_type           15750 non-null  str
#  10  is_premium_user             15750 non-null  int64
#  11  total_visits                15750 non-null  int64
#  12  avg_session_time            15750 non-null  float64
#  13  pages_per_session           15750 non-null  float64
#  14  email_open_rate             15750 non-null  float64
#  15  email_click_rate            15750 non-null  float64
#  16  total_spent                 14640 non-null  float64
#  17  avg_order_value             15750 non-null  float64
#  18  discount_used               15750 non-null  int64
#  19  coupon_code                 9305 non-null   str
#  20  support_tickets             15750 non-null  int64
#  21  refund_requested            15750 non-null  int64
#  22  delivery_delay_days         15750 non-null  int64
#  23  payment_method              15750 non-null  str
#  24  satisfaction_score          15014 non-null  float64
#  25  nps_score                   15750 non-null  int64
#  26  marketing_spend_per_user    15750 non-null  float64
#  27  lifetime_value              15750 non-null  float64
#  28  last_3_month_purchase_freq  15750 non-null  int64
#  29  churn                       15750 non-null  int64
# dtypes: datetime64[us](2), float64(9), int64(9), str(10)
# memory usage: 3.6 MB
# None
#
# Tipos de datos por columna:
# customer_id                              str
# gender                                   str
# age                                      str
# country                                  str
# city                                     str
# signup_date                   datetime64[us]
# last_purchase_date            datetime64[us]
# acquisition_channel                      str
# device_type                              str
# subscription_type                        str
# is_premium_user                        int64
# total_visits                           int64
# avg_session_time                     float64
# pages_per_session                    float64
# email_open_rate                      float64
# email_click_rate                     float64
# total_spent                          float64
# avg_order_value                      float64
# discount_used                          int64
# coupon_code                              str
# support_tickets                        int64
# refund_requested                       int64
# delivery_delay_days                    int64
# payment_method                           str
# satisfaction_score                   float64
# nps_score                              int64
# marketing_spend_per_user             float64
# lifetime_value                       float64
# last_3_month_purchase_freq             int64
# churn                                  int64
# dtype: object

# %%
# Conteo de valores nulos
df.isnull().sum().sort_values(ascending=False)
# Out:
# coupon_code                   6445
# country                       1585
# city                          1565
# total_spent                   1110
# satisfaction_score             736
# gender                           0
# last_purchase_date               0
# acquisition_channel              0
# device_type                      0
# subscription_type                0
# is_premium_user                  0
# customer_id                      0
# age                              0
# signup_date                      0
# pages_per_session                0
# avg_session_time                 0
# total_visits                     0
# email_click_rate                 0
# avg_order_value                  0
# discount_used                    0
# support_tickets                  0
# email_open_rate                  0
# refund_requested                 0
# delivery_delay_days              0
# payment_method                   0
# nps_score                        0
# marketing_spend_per_user         0
# lifetime_value                   0
# last_3_month_purchase_freq       0
# churn                            0
# dtype: int64

# %%
# Estadísticas descriptivas del dataset
df.describe(include='all').T
# Out:
#                               count unique      top  freq  \
# customer_id                   15750  13250     nan   1056
# gender                        15750      8    male   4573
# age                           15750     78     nan   1844
# country                       14165      5  Germany  2883
# city                          14185      7   London  2122
# signup_date                   15750    NaN      NaN   NaN
# last_purchase_date            15750    NaN      NaN   NaN
# acquisition_channel           15750      5  Organic  3211
# device_type                   15750      3   Tablet  5296
# subscription_type             15750      2  Monthly  8029
# is_premium_user             15750.0    NaN      NaN   NaN
# total_visits                15750.0    NaN      NaN   NaN
# avg_session_time            15750.0    NaN      NaN   NaN
# pages_per_session           15750.0    NaN      NaN   NaN
# email_open_rate             15750.0    NaN      NaN   NaN
# email_click_rate            15750.0    NaN      NaN   NaN
# total_spent                 14640.0    NaN      NaN   NaN
# avg_order_value             15750.0    NaN      NaN   NaN
# discount_used               15750.0    NaN      NaN   NaN
# coupon_code                    9305      3    REF10  3144
# support_tickets             15750.0    NaN      NaN   NaN
# refund_requested            15750.0    NaN      NaN   NaN
# delivery_delay_days         15750.0    NaN      NaN   NaN
# payment_method                15750      5      UPI  3266
# satisfaction_score          15014.0    NaN      NaN   NaN
# nps_score                   15750.0    NaN      NaN   NaN
# marketing_spend_per_user    15750.0    NaN      NaN   NaN
# lifetime_value              15750.0    NaN      NaN   NaN
# last_3_month_purchase_freq  15750.0    NaN      NaN   NaN
# churn                       15750.0    NaN      NaN   NaN
#
#                                                   mean                  min  \
# customer_id                                        NaN                  NaN
# gender                                             NaN                  NaN
# age                                                NaN                  NaN
# country                                            NaN                  NaN
# city                                               NaN                  NaN
# signup_date                 2023-05-15 22:34:14.400000  2022-01-01 00:00:00
# last_purchase_date          2024-02-05 08:48:05.485714  2023-01-01 00:00:00
# acquisition_channel                                NaN                  NaN
# device_type                                        NaN                  NaN
# subscription_type                                  NaN                  NaN
# is_premium_user                               0.304571                  0.0
# total_visits                                 14.996635                  3.0
# avg_session_time                              8.021602             0.006095
# pages_per_session                             3.999655             0.007845
# email_open_rate                               0.495542                  0.0
# email_click_rate                              0.251363                  0.0
# total_spent                                 524.036282             0.267291
# avg_order_value                              60.084236             0.071596
# discount_used                                 0.493968                  0.0
# coupon_code                                        NaN                  NaN
# support_tickets                               1.997778                  0.0
# refund_requested                              0.147556                  0.0
# delivery_delay_days                            2.98654                  0.0
# payment_method                                     NaN                  NaN
# satisfaction_score                            3.590049                  1.0
# nps_score                                     4.974222                  0.0
# marketing_spend_per_user                     17.584185                  5.0
# lifetime_value                             1234.659465             0.368886
# last_3_month_purchase_freq                     6.98254                  0.0
# churn                                         0.153333                  0.0
#
#                                             25%                  50%  \
# customer_id                                 NaN                  NaN
# gender                                      NaN                  NaN
# age                                         NaN                  NaN
# country                                     NaN                  NaN
# city                                        NaN                  NaN
# signup_date                 2022-09-05 00:00:00  2023-05-20 00:00:00
# last_purchase_date          2023-07-18 00:00:00  2024-02-08 00:00:00
# acquisition_channel                         NaN                  NaN
# device_type                                 NaN                  NaN
# subscription_type                           NaN                  NaN
# is_premium_user                             0.0                  0.0
# total_visits                               12.0                 15.0
# avg_session_time                       5.984179             7.992879
# pages_per_session                      2.987546             3.994116
# email_open_rate                            0.24                  0.5
# email_click_rate                           0.13                 0.25
# total_spent                          299.418682           498.217585
# avg_order_value                       43.020706            60.108827
# discount_used                               0.0                  0.0
# coupon_code                                 NaN                  NaN
# support_tickets                             1.0                  2.0
# refund_requested                            0.0                  0.0
# delivery_delay_days                         2.0                  3.0
# payment_method                              NaN                  NaN
# satisfaction_score                          3.0                  4.0
# nps_score                                   2.0                  5.0
# marketing_spend_per_user                  11.37                17.63
# lifetime_value                       739.878947          1215.731652
# last_3_month_purchase_freq                  3.0                  7.0
# churn                                       0.0                  0.0
#
#                                             75%                  max  \
# customer_id                                 NaN                  NaN
# gender                                      NaN                  NaN
# age                                         NaN                  NaN
# country                                     NaN                  NaN
# city                                        NaN                  NaN
# signup_date                 2024-01-21 00:00:00  2024-09-26 00:00:00
# last_purchase_date          2024-08-25 00:00:00  2025-03-10 00:00:00
# acquisition_channel                         NaN                  NaN
# device_type                                 NaN                  NaN
# subscription_type                           NaN                  NaN
# is_premium_user                             1.0                  1.0
# total_visits                               18.0                 31.0
# avg_session_time                      10.059595            19.123716
# pages_per_session                      5.010743            10.843172
# email_open_rate                            0.75                  1.0
# email_click_rate                           0.38                  0.5
# total_spent                          701.540023         15910.431879
# avg_order_value                       76.866131           154.554696
# discount_used                               1.0                  1.0
# coupon_code                                 NaN                  NaN
# support_tickets                             3.0                  9.0
# refund_requested                            0.0                  1.0
# delivery_delay_days                         4.0                 11.0
# payment_method                              NaN                  NaN
# satisfaction_score                          4.0                  5.0
# nps_score                                   8.0                 10.0
# marketing_spend_per_user                  23.78                 30.0
# lifetime_value                      1677.041348          3767.490455
# last_3_month_purchase_freq                 11.0                 14.0
# churn                                       0.0                  1.0
#
#                                    std
# customer_id                        NaN
# gender                             NaN
# age                                NaN
# country                            NaN
# city                               NaN
# signup_date                        NaN
# last_purchase_date                 NaN
# acquisition_channel                NaN
# device_type                        NaN
# subscription_type                  NaN
# is_premium_user                0.46024
# total_visits                  3.891888
# avg_session_time              2.990873
# pages_per_session             1.479826
# email_open_rate               0.290067
# email_click_rate              0.144735
# total_spent                 469.589164
# avg_order_value              24.713662
# discount_used                 0.499979
# coupon_code                        NaN
# support_tickets               1.422918
# refund_requested               0.35467
# delivery_delay_days           1.718842
# payment_method                     NaN
# satisfaction_score            1.089169
# nps_score                     3.155016
# marketing_spend_per_user      7.184123
# lifetime_value              656.873619
# last_3_month_purchase_freq    4.324731
# churn                          0.36032

# %%
# seleccion de columnas numericas
columnas_numericas = []
for col in df.columns:
    if is_float_dtype(df[col]) or is_integer_dtype(df[col]):
        columnas_numericas.append(col)
print('Columnas numéricas identificadas:', columnas_numericas)
# Out:
# Columnas numéricas identificadas: ['is_premium_user', 'total_visits', 'avg_session_time', 'pages_per_session', 'email_open_rate', 'email_click_rate', 'total_spent', 'avg_order_value', 'discount_used', 'support_tickets', 'refund_requested', 'delivery_delay_days', 'satisfaction_score', 'nps_score', 'marketing_spend_per_user', 'lifetime_value', 'last_3_month_purchase_freq', 'churn']

# %%
# Detección de outliers por IQR para las columnas numéricas
filas_outliers = []

for columna in columnas_numericas:

    serie = pd.to_numeric(df[columna], errors='coerce')
    q1 = serie.quantile(0.25)
    q3 = serie.quantile(0.75)
    iqr = q3 - q1
    limite_inferior = q1 - 1.5 * iqr
    limite_superior = q3 + 1.5 * iqr
    cantidad_outliers = int(((serie < limite_inferior) | (serie > limite_superior)).sum())
    filas_outliers.append({'columna': columna, 'outliers_iqr': cantidad_outliers, 'lim_inf': limite_inferior, 'lim_sup': limite_superior})

df_outliers = pd.DataFrame(filas_outliers).sort_values('outliers_iqr', ascending=False)
df_outliers
# Out:
#                        columna  outliers_iqr     lim_inf      lim_sup
# 17                       churn          2415    0.000000     0.000000
# 10            refund_requested          2324    0.000000     0.000000
# 12          satisfaction_score           791    1.500000     5.500000
# 11         delivery_delay_days           195   -1.000000     7.000000
# 9              support_tickets            85   -2.000000     6.000000
# 6                  total_spent            85 -303.763329  1304.722034
# 15              lifetime_value            58 -665.864653  3082.784948
# 7              avg_order_value            57   -7.747431   127.634267
# 2             avg_session_time            46   -0.128945    16.172719
# 1                 total_visits            42    3.000000    27.000000
# 3            pages_per_session            39   -0.047248     8.045537
# 0              is_premium_user             0   -1.500000     2.500000
# 4              email_open_rate             0   -0.525000     1.515000
# 5             email_click_rate             0   -0.245000     0.755000
# 8                discount_used             0   -1.500000     2.500000
# 13                   nps_score             0   -7.000000    17.000000
# 14    marketing_spend_per_user             0   -7.245000    42.395000
# 16  last_3_month_purchase_freq             0   -9.000000    23.000000

# %%
# Distribuciones numéricas (histogramas)
n_cols = len(columnas_numericas)
ncols = 3
nrows = int(np.ceil(n_cols / ncols))

fig, ejes = plt.subplots(nrows, ncols, figsize=(16, 4 * nrows))
ejes = np.atleast_1d(ejes).flatten()

for indice, columna in enumerate(columnas_numericas):
    pd.to_numeric(df[columna], errors='coerce').hist(
        ax=ejes[indice], bins=30, color='steelblue', edgecolor='black'
    )
    ejes[indice].set_title(columna)
    ejes[indice].grid(alpha=0.2)

# Oculta ejes sobrantes cuando la grilla es mayor al número de variables
for i in range(n_cols, len(ejes)):
    ejes[i].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# Boxplots para inspección visual de outliers
n_cols = len(columnas_numericas)
ncols = 3
nrows = int(np.ceil(n_cols / ncols))

fig, ejes = plt.subplots(nrows, ncols, figsize=(16, 4 * nrows))
ejes = np.atleast_1d(ejes).flatten()

for indice, columna in enumerate(columnas_numericas):
    ejes[indice].boxplot(pd.to_numeric(df[columna], errors='coerce').dropna(), vert=True)
    ejes[indice].set_title(columna)
    ejes[indice].grid(alpha=0.2)

# Oculta ejes sobrantes cuando la grilla es mayor al número de variables
for i in range(n_cols, len(ejes)):
    ejes[i].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# Revisión de correlacon entre variables numéricas
df.corr('spearman',numeric_only=True)
# Out:
#                             is_premium_user  total_visits  avg_session_time  \
# is_premium_user                    1.000000      0.017527          0.002475
# total_visits                       0.017527      1.000000         -0.001652
# avg_session_time                   0.002475     -0.001652          1.000000
# pages_per_session                  0.004252      0.007531         -0.002942
# email_open_rate                   -0.002841     -0.005101          0.006850
# email_click_rate                  -0.004938      0.009899          0.006695
# total_spent                        0.008463      0.004935          0.009530
# avg_order_value                    0.004211     -0.011858         -0.001690
# discount_used                      0.008122     -0.005358         -0.000108
# support_tickets                    0.010220      0.000422          0.007149
# refund_requested                   0.003569     -0.001399         -0.004253
# delivery_delay_days               -0.007384      0.005255         -0.007495
# satisfaction_score                -0.001720     -0.012425         -0.012205
# nps_score                         -0.006424      0.001708         -0.007649
# marketing_spend_per_user           0.014045      0.012242         -0.009069
# lifetime_value                     0.008325     -0.009448          0.001423
# last_3_month_purchase_freq        -0.001484     -0.004997         -0.000863
# churn                             -0.008247      0.017302          0.017903
#
#                             pages_per_session  email_open_rate  \
# is_premium_user                      0.004252        -0.002841
# total_visits                         0.007531        -0.005101
# avg_session_time                    -0.002942         0.006850
# pages_per_session                    1.000000        -0.006176
# email_open_rate                     -0.006176         1.000000
# email_click_rate                     0.003574         0.001809
# total_spent                         -0.006452         0.000209
# avg_order_value                     -0.000123        -0.001322
# discount_used                        0.009849        -0.010159
# support_tickets                      0.010725         0.000032
# refund_requested                    -0.004243         0.012462
# delivery_delay_days                  0.009523        -0.003159
# satisfaction_score                  -0.014497        -0.001428
# nps_score                            0.003380        -0.009439
# marketing_spend_per_user             0.002461         0.006808
# lifetime_value                       0.001063         0.004084
# last_3_month_purchase_freq          -0.001309        -0.015167
# churn                                0.003855        -0.008424
#
#                             email_click_rate  total_spent  avg_order_value  \
# is_premium_user                    -0.004938     0.008463         0.004211
# total_visits                        0.009899     0.004935        -0.011858
# avg_session_time                    0.006695     0.009530        -0.001690
# pages_per_session                   0.003574    -0.006452        -0.000123
# email_open_rate                     0.001809     0.000209        -0.001322
# email_click_rate                    1.000000     0.014403         0.002579
# total_spent                         0.014403     1.000000        -0.000748
# avg_order_value                     0.002579    -0.000748         1.000000
# discount_used                      -0.017140    -0.007351        -0.020508
# support_tickets                    -0.013978    -0.000877        -0.002415
# refund_requested                    0.003293    -0.008321         0.001794
# delivery_delay_days                 0.008419     0.011458         0.003762
# satisfaction_score                 -0.000029    -0.004968        -0.013859
# nps_score                          -0.012652     0.004090         0.004864
# marketing_spend_per_user            0.001524     0.010664         0.004983
# lifetime_value                     -0.021998    -0.008881        -0.005943
# last_3_month_purchase_freq         -0.001377    -0.005800         0.001275
# churn                              -0.000619    -0.257136         0.000015
#
#                             discount_used  support_tickets  refund_requested  \
# is_premium_user                  0.008122         0.010220          0.003569
# total_visits                    -0.005358         0.000422         -0.001399
# avg_session_time                -0.000108         0.007149         -0.004253
# pages_per_session                0.009849         0.010725         -0.004243
# email_open_rate                 -0.010159         0.000032          0.012462
# email_click_rate                -0.017140        -0.013978          0.003293
# total_spent                     -0.007351        -0.000877         -0.008321
# avg_order_value                 -0.020508        -0.002415          0.001794
# discount_used                    1.000000         0.013609          0.004661
# support_tickets                  0.013609         1.000000          0.009128
# refund_requested                 0.004661         0.009128          1.000000
# delivery_delay_days              0.006762         0.014895         -0.003088
# satisfaction_score               0.001287         0.004775          0.003198
# nps_score                        0.004301        -0.003336         -0.007661
# marketing_spend_per_user        -0.003805        -0.001621         -0.016309
# lifetime_value                   0.007271         0.006159         -0.003410
# last_3_month_purchase_freq       0.000039        -0.001621          0.001338
# churn                           -0.001034         0.086818         -0.009116
#
#                             delivery_delay_days  satisfaction_score  \
# is_premium_user                       -0.007384           -0.001720
# total_visits                           0.005255           -0.012425
# avg_session_time                      -0.007495           -0.012205
# pages_per_session                      0.009523           -0.014497
# email_open_rate                       -0.003159           -0.001428
# email_click_rate                       0.008419           -0.000029
# total_spent                            0.011458           -0.004968
# avg_order_value                        0.003762           -0.013859
# discount_used                          0.006762            0.001287
# support_tickets                        0.014895            0.004775
# refund_requested                      -0.003088            0.003198
# delivery_delay_days                    1.000000           -0.001024
# satisfaction_score                    -0.001024            1.000000
# nps_score                             -0.003686           -0.009024
# marketing_spend_per_user               0.004040           -0.014413
# lifetime_value                         0.006863           -0.019238
# last_3_month_purchase_freq             0.001668            0.002197
# churn                                  0.002038           -0.261377
#
#                             nps_score  marketing_spend_per_user  \
# is_premium_user             -0.006424                  0.014045
# total_visits                 0.001708                  0.012242
# avg_session_time            -0.007649                 -0.009069
# pages_per_session            0.003380                  0.002461
# email_open_rate             -0.009439                  0.006808
# email_click_rate            -0.012652                  0.001524
# total_spent                  0.004090                  0.010664
# avg_order_value              0.004864                  0.004983
# discount_used                0.004301                 -0.003805
# support_tickets             -0.003336                 -0.001621
# refund_requested            -0.007661                 -0.016309
# delivery_delay_days         -0.003686                  0.004040
# satisfaction_score          -0.009024                 -0.014413
# nps_score                    1.000000                 -0.023813
# marketing_spend_per_user    -0.023813                  1.000000
# lifetime_value              -0.000327                  0.002698
# last_3_month_purchase_freq   0.013856                  0.001094
# churn                        0.006520                 -0.005459
#
#                             lifetime_value  last_3_month_purchase_freq  \
# is_premium_user                   0.008325                   -0.001484
# total_visits                     -0.009448                   -0.004997
# avg_session_time                  0.001423                   -0.000863
# pages_per_session                 0.001063                   -0.001309
# email_open_rate                   0.004084                   -0.015167
# email_click_rate                 -0.021998                   -0.001377
# total_spent                      -0.008881                   -0.005800
# avg_order_value                  -0.005943                    0.001275
# discount_used                     0.007271                    0.000039
# support_tickets                   0.006159                   -0.001621
# refund_requested                 -0.003410                    0.001338
# delivery_delay_days               0.006863                    0.001668
# satisfaction_score               -0.019238                    0.002197
# nps_score                        -0.000327                    0.013856
# marketing_spend_per_user          0.002698                    0.001094
# lifetime_value                    1.000000                    0.008664
# last_3_month_purchase_freq        0.008664                    1.000000
# churn                             0.008337                    0.003030
#
#                                churn
# is_premium_user            -0.008247
# total_visits                0.017302
# avg_session_time            0.017903
# pages_per_session           0.003855
# email_open_rate            -0.008424
# email_click_rate           -0.000619
# total_spent                -0.257136
# avg_order_value             0.000015
# discount_used              -0.001034
# support_tickets             0.086818
# refund_requested           -0.009116
# delivery_delay_days         0.002038
# satisfaction_score         -0.261377
# nps_score                   0.006520
# marketing_spend_per_user   -0.005459
# lifetime_value              0.008337
# last_3_month_purchase_freq  0.003030
# churn                       1.000000

# %% [markdown]
# ## EDA focalizado en 20 columnas seleccionadas
# A partir del análisis general del dataset, se profundiza en las 15 variables numéricas y 5 categóricas elegidas para el informe, incluyendo nulos, tipos de datos, visualizaciones y detección de outliers por IQR.

# %%
# Selección de columnas a utilizar, para este dataset se utilizarán: 15 numéricas y 5 categóricas
columnas_numericas = [
    'age', 'total_spent', 'avg_order_value', 'lifetime_value',
    'last_3_month_purchase_freq', 'marketing_spend_per_user',
    'total_visits', 'avg_session_time', 'pages_per_session',
    'email_open_rate', 'email_click_rate', 'support_tickets',
    'delivery_delay_days', 'satisfaction_score', 'nps_score'
]

columnas_categoricas = ['gender', 'country', 'acquisition_channel', 'subscription_type', 'payment_method']
columnas_seleccionadas = columnas_numericas + columnas_categoricas

print('Columnas numéricas seleccionadas:', columnas_numericas)
print('\nColumnas categóricas seleccionadas:', columnas_categoricas)
# Out:
# Columnas numéricas seleccionadas: ['age', 'total_spent', 'avg_order_value', 'lifetime_value', 'last_3_month_purchase_freq', 'marketing_spend_per_user', 'total_visits', 'avg_session_time', 'pages_per_session', 'email_open_rate', 'email_click_rate', 'support_tickets', 'delivery_delay_days', 'satisfaction_score', 'nps_score']
#
# Columnas categóricas seleccionadas: ['gender', 'country', 'acquisition_channel', 'subscription_type', 'payment_method']

# %%
# Frecuencias absolutas de categóricas
for columna in columnas_categoricas:
    print(f'\n{columna}')
    print(df[columna].value_counts(dropna=False))
# Out:
# gender
# gender
# male       4573
# female     4401
# FEMALE     1930
# MALE       1906
# nan        1554
# NAN         687
# other       497
# OTHER       202
# Name: count, dtype: int64
#
# country
# country
# Germany       2883
# Bangladesh    2833
# India         2822
# USA           2816
# UK            2811
# NaN           1585
# Name: count, dtype: int64
#
# acquisition_channel
# acquisition_channel
# Organic         3211
# Google Ads      3185
# Facebook Ads    3170
# Referral        3108
# Email           3076
# Name: count, dtype: int64
#
# subscription_type
# subscription_type
# Monthly    8029
# Annual     7721
# Name: count, dtype: int64
#
# payment_method
# payment_method
# UPI       3266
# PayPal    3162
# SEPA      3118
# BKash     3114
# Card      3090
# Name: count, dtype: int64

# %%
# Visualización de categóricas (top categorías)
fig, ejes = plt.subplots(3, 2, figsize=(14, 12))
ejes = ejes.flatten()

for indice, columna in enumerate(columnas_categoricas):
    conteo_valores = df[columna].astype(str).value_counts(dropna=False).head(10)
    conteo_valores.plot(kind='bar', ax=ejes[indice], color='coral', edgecolor='black')
    ejes[indice].set_title(columna)
    ejes[indice].tick_params(axis='x', rotation=45)
    ejes[indice].grid(axis='y', alpha=0.2)

# Oculta el subplot sobrante
if len(columnas_categoricas) < len(ejes):
    for indice in range(len(columnas_categoricas), len(ejes)):
        ejes[indice].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# Resumen rápido por columna numérica: tipo, nulos y posible señal de outliers (IQR)
resumen_rapido_numerico = []
for columna in columnas_numericas:
    serie = pd.to_numeric(df[columna], errors='coerce')
    q1 = serie.quantile(0.25)
    q3 = serie.quantile(0.75)
    iqr = q3 - q1
    limite_inferior = q1 - 1.5 * iqr
    limite_superior = q3 + 1.5 * iqr
    cantidad_outliers = int(((serie < limite_inferior) | (serie > limite_superior)).sum())
    resumen_rapido_numerico.append({
        'columna': columna,
        'dtype': str(df[columna].dtype),
        'nulos': int(df[columna].isnull().sum()),
        'outliers_iqr': cantidad_outliers
    })

pd.DataFrame(resumen_rapido_numerico).sort_values(['outliers_iqr', 'nulos'], ascending=False)
# Out:
#                        columna    dtype  nulos  outliers_iqr
# 13          satisfaction_score  float64    736           791
# 0                          age      str      0           399
# 12         delivery_delay_days    int64      0           195
# 1                  total_spent  float64   1110            85
# 11             support_tickets    int64      0            85
# 3               lifetime_value  float64      0            58
# 2              avg_order_value  float64      0            57
# 7             avg_session_time  float64      0            46
# 6                 total_visits    int64      0            42
# 8            pages_per_session  float64      0            39
# 4   last_3_month_purchase_freq    int64      0             0
# 5     marketing_spend_per_user  float64      0             0
# 9              email_open_rate  float64      0             0
# 10            email_click_rate  float64      0             0
# 14                   nps_score    int64      0             0

# %%
# Resumen rápido por columna categórica: tipo, nulos y cardinalidad
resumen_rapido_categorico = []
for columna in columnas_categoricas:
    resumen_rapido_categorico.append({
        'columna': columna,
        'dtype': str(df[columna].dtype),
        'nulos': int(df[columna].isnull().sum()),
        'unicos': int(df[columna].nunique(dropna=True))
    })

pd.DataFrame(resumen_rapido_categorico).sort_values(['nulos', 'unicos'], ascending=False)
# Out:
#                columna dtype  nulos  unicos
# 1              country   str   1585       5
# 0               gender   str      0       8
# 2  acquisition_channel   str      0       5
# 4       payment_method   str      0       5
# 3    subscription_type   str      0       2
